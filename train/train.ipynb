# %%
# !nvidia-smi
# Out:
# Fri Oct 20 15:46:59 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    10W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla T4            Off  | 00000000:00:05.0 Off |                    0 |
# | N/A   41C    P8    10W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /kaggle/working

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.134
# !pip install fastapi kaleido python-multipart uvicorn
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5017.2/8062.4 GB disk)

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="6wSf6bKIXaStRffQqY1f")
project = rf.workspace("minecraft-object-detection").project("minecraft-mob-detection")
dataset = project.version(10).download("yolov8")
# Out:
# mkdir: cannot create directory ‘/kaggle/working/datasets’: File exists
# /kaggle/working/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Minecraft-Mob-Detection-10 to yolov8:: 100%|██████████| 432223/432223 [00:06<00:00, 70191.79it/s]
# Extracting Dataset Version Zip to Minecraft-Mob-Detection-10 in yolov8:: 100%|██████████| 5780/5780 [00:01<00:00, 3002.52it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=30 imgsz=800 plots=True
# Out:
# /kaggle/working
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# New https://pypi.org/project/ultralytics/8.0.200 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/kaggle/working/datasets/Minecraft-Mob-Detection-10/data.yaml, epochs=30, patience=50, batch=16, imgsz=800, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/detect/train3
# Overriding model.yaml nc=80 with nc=17
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2122627  ultralytics.nn.modules.head.Detect           [17, [128, 256, 512]]
# Model summary: 225 layers, 11142179 parameters, 11142163 gradients
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train3', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /kaggle/working/datasets/Minecraft-Mob-Detection-10/train/labels
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/working/datasets/Minecraft-Mob-Detection-10/valid/labels.c
# Plotting labels to runs/detect/train3/labels.jpg...
# optimizer: AdamW(lr=0.000476, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      6.48G      1.301      4.166      1.172          6        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697       0.57      0.197      0.241      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      6.52G      1.163      1.474      1.123          9        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.481      0.304      0.347      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      6.53G      1.133       1.15      1.106         14        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.541      0.299      0.401      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      6.55G      1.106      1.042      1.103          4        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.528      0.386      0.441       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      6.29G      1.094     0.9338      1.083          6        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.516      0.377       0.42      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      6.55G      1.075     0.8673      1.077          6        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.635      0.385      0.453      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      6.55G      1.047     0.8038      1.061          9        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.635      0.455      0.469       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      6.54G      1.017     0.7552      1.049          7        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.586      0.359      0.462      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      6.57G      1.002     0.7353      1.032         16        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.538      0.439      0.422      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      6.52G     0.9971     0.6999      1.037          8        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.593      0.514      0.492      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      6.53G     0.9669     0.6713      1.013          6        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.617      0.417      0.501      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      6.29G     0.9539     0.6503      1.016          9        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.662      0.417      0.511      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      6.29G     0.9417      0.635      1.006         10        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.681      0.455      0.558      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      6.52G      0.949     0.6195      1.007         21        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697       0.74      0.527      0.567      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      6.52G     0.9219     0.6028     0.9898         16        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697       0.62      0.536      0.569      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      6.57G     0.9077     0.5711      0.988         14        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.469      0.554      0.506      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      6.55G     0.8971     0.5612     0.9818         13        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.577      0.517      0.553      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      6.51G     0.8899     0.5419      0.981          7        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.774      0.466      0.555      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      6.54G     0.8684      0.538     0.9814          7        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.629      0.546      0.554       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      6.56G     0.8576     0.5161     0.9617         11        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.605      0.548      0.541      0.363
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      6.54G     0.8406     0.4976     0.9498          7        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697       0.61      0.522       0.54      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      6.52G     0.8174     0.4702     0.9335          4        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.609      0.509      0.576      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      6.54G      0.816     0.4525     0.9373          7        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.647      0.523      0.562      0.401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      6.54G     0.7979     0.4406     0.9274         10        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.614       0.59      0.548      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      6.54G     0.7816     0.4295     0.9239          4        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.666      0.566      0.577      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30       6.5G     0.7739     0.4174     0.9242          4        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.703      0.519      0.606      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      6.56G     0.7644      0.411     0.9177          4        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.673      0.578      0.606        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      6.53G     0.7427     0.3954     0.9114          4        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.667      0.561      0.577      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      6.31G     0.7285     0.3829     0.9068          3        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.644      0.576      0.576      0.389
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30       6.5G     0.7176      0.375     0.8972          4        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697       0.65      0.598      0.587      0.388
#
# 30 epochs completed in 0.588 hours.
# Optimizer stripped from runs/detect/train3/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train3/weights/best.pt, 22.5MB
#
# Validating runs/detect/train3/weights/best.pt...
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 11132163 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        422        697      0.703       0.52      0.607      0.419
#                chicken        422         14      0.218      0.714      0.342      0.234
#                    cow        422        127      0.828       0.48      0.631      0.426
#                creeper        422        123      0.988      0.984      0.993      0.842
#               enderman        422        103      0.995      0.835      0.961       0.67
#                    pig        422         48        0.6      0.333      0.458      0.225
#                  sheep        422        126      0.952      0.159      0.529      0.376
#               skeleton        422          8      0.289      0.561      0.371      0.231
#                 spider        422          8      0.458      0.625      0.627      0.519
#                   wolf        422        138          1     0.0123      0.326      0.232
#                 zombie        422          2      0.705        0.5      0.828      0.431
# Speed: 0.7ms preprocess, 3.9ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs/detect/train3

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# F1_curve.png					   train_batch1.jpg
# PR_curve.png					   train_batch2.jpg
# P_curve.png					   train_batch2900.jpg
# R_curve.png					   train_batch2901.jpg
# args.yaml					   train_batch2902.jpg
# confusion_matrix.png				   val_batch0_labels.jpg
# confusion_matrix_normalized.png			   val_batch0_pred.jpg
# events.out.tfevents.1697814341.a053728e3c63.103.0  val_batch1_labels.jpg
# labels.jpg					   val_batch1_pred.jpg
# labels_correlogram.jpg				   val_batch2_labels.jpg
# results.csv					   val_batch2_pred.jpg
# results.png					   weights
# train_batch0.jpg

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=val model={HOME}/runs/detect/train2/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /kaggle/working
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Traceback (most recent call last):
#   File "/opt/conda/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/opt/conda/lib/python3.10/site-packages/ultralytics/yolo/cfg/__init__.py", line 380, in entrypoint
#     model = YOLO(model, task=task)
#   File "/opt/conda/lib/python3.10/site-packages/ultralytics/yolo/engine/model.py", line 107, in __init__
#     self._load(model, task)
#   File "/opt/conda/lib/python3.10/site-packages/ultralytics/yolo/engine/model.py", line 156, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/opt/conda/lib/python3.10/site-packages/ultralytics/nn/tasks.py", line 578, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#   File "/opt/conda/lib/python3.10/site-packages/ultralytics/nn/tasks.py", line 518, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
#   File "/opt/conda/lib/python3.10/site-packages/torch/serialization.py", line 791, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/opt/conda/lib/python3.10/site-packages/torch/serialization.py", line 271, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/opt/conda/lib/python3.10/site-packages/torch/serialization.py", line 252, in __init__
#     super().__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/runs/detect/train2/weights/best.pt'

# %% [markdown]
# ## infer

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True

# %% [markdown]
# ## Inference with Custom Model

# %%
# import glob
# from IPython.display import Image, display

# for image_path in glob.glob(f'{HOME}/runs/detect/predict3/*.jpg')[:3]:
#       display(Image(filename=image_path, width=600))
#       print("\n")

# %% [markdown]
# ## export

# %%
# !yolo export model={HOME}/runs/detect/train/weights/best.pt format=onnx
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.0 CPU
# Model summary (fused): 168 layers, 11132163 parameters, 0 gradients
#
# PyTorch: starting from /kaggle/working/runs/detect/train/weights/best.pt with input shape (1, 3, 800, 800) BCHW and output shape(s) (1, 21, 13125) (21.5 MB)
#
# ONNX: starting export with onnx 1.14.1 opset 17...
# ================ Diagnostic Run torch.onnx.export version 2.0.0 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: export success ✅ 1.4s, saved as /kaggle/working/runs/detect/train/weights/best.onnx (42.8 MB)
#
# Export complete (2.5s)
# Results saved to /kaggle/working/runs/detect/train/weights
# Predict:         yolo predict task=detect model=/kaggle/working/runs/detect/train/weights/best.onnx imgsz=800
# Validate:        yolo val task=detect model=/kaggle/working/runs/detect/train/weights/best.onnx imgsz=800 data=/kaggle/working/datasets/Minecraft-Mob-Detection-10/data.yaml
# Visualize:       https://netron.app
